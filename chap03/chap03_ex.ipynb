# %% [markdown]
# 평년과 윤년을 구분하는 프로그램

# %%
year=int(input("년도를 입력하세요 : "))
if(year%4==00):
    print(year, "년은 윤년입니다")

else:
    print(year, "년은 평년입니다." )
# Out:
# 2025 년은 평년입니다.

# %% [markdown]
# 숫자 맞추기 게임 프로그램

# %%
from random import randint
secret_num = randint(1,100)
num_guesses = 0
while guess != secret_num and num_guesses <= 4:
    guess = eval(input('Enter your guess (1-100): '))
    num_guesses = num_guesses +1
    if guess < secret_num:
        print(' 더큽니다.', 5-num_guesses, '번 남았습니다.\n')
    elif guess > secret_num:
        print(' 더작습니다.', 5-num_guesses, '번 남았습니다.\n')
    else:
        print('맞았습니다!')
if num_guesses==5 and guess != secret_num:
    print('당신이 졌습니다. 정답은 ', secret_num, '입니다')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 secret_num = randint(1,100)
#       3 num_guesses = 0
# ----> 4 while guess != secret_num and num_guesses <=4:
#       5     guess = eval(input('Enter your guess (1-100): '))
#       6     num_guesses = num_guesses +1
#
# NameError: name 'guess' is not defined
