# %% [markdown]
# >>> def welcome(name):
# ...     print("Hello," , name)
# ...
# >>> welcome('John')
# Hello, John
# >>> def prtStr(str):
# ...     print("%s" %str)
# ...     return
# ...
# >>> str = "welcome to Python"
# >>> prtStr(str)
# welcome to Python

# %% [markdown]
# >>> def squareArea(s):
# ...     area = s*s
# ...     return area
# ...
# >>> a= squareArea(5)
# >>> b= squareArea(7)
# >>> print("한변의 길이가 %d인 정사각형의 넓이는 %d" %(5,a))
# 한변의 길이가 5인 정사각형의 넓이는 25
# >>> print("한변의 길이가 %d인 정사각형의 넓이는 %d" %(7,b))
# 한변의 길이가 7인 정사각형의 넓이는 49

# %% [markdown]
# >>> def sum(n):
# ...     hab=0
# ...     for i in range(1, n+1):
# ...             hab = hab+1
# ...     return hab
# ...
# >>> a=sum(50)
# >>> b=sum(1000)
# >>> print(a)
# 50
# >>> print(b)
# 1000

# %% [markdown]
# >>> lambda parameters: expr
# <function <lambda> at 0x0000020895CAF060>
# >>> sum = lambda x, y: x+y
# >>> print("정수의 합: ", sum(10,20))
# 정수의 합:  30
# >>> print("정수의 합: ", sum(20,20))
# 정수의 합:  40

# %% [markdown]
# >>> def fact(n):
# ...     if n==1:
# ...             return 1
# ...     else:
# ...             return n*fact(n-1)
# ...
# >>> print(fact(5))
# 120
